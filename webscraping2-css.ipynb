# %%
import requests

# %%
il_mental_health_html = requests.get("https://www.dhs.state.il.us/page.aspx?item=43695").text

print(il_mental_health_html)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# 	<head>
# 		<meta charset="utf-8">
# 		<meta name="viewport" content="width=device-width, initial-scale=1">
#
# 		<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 		<title>IDHS: Non-Crisis: Mental Health Partners/Providers</title>
#
# 		<meta property="og:title" content="IDHS: Non-Crisis: Mental Health Partners/Providers">
# 		<meta property="og:type" content="website">
# 		<meta property="og:url" content="https://www.dhs.state.il.us/page.aspx?item=43695">
#         <!-- Google tag (gtag.js) -->
#         <script async src="https://www.googletagmanager.com/gtag/js?id=G-2ZG8HEE2NT"></script>
# 		<script type="text/javascript" src="Custom_DHS/Config_WebSite/gtag2.js"></script>
# <style type="text/css">@import "Custom_DHS/Config_WebSite/Page.css";</style>
# 		<style type="text/css">@import "Custom_DHS/Config_WebSite/Site.css";</style>
# 		<style type="text/css">@import "Custom_DHS/Config_WebSite/SiteScreen.css";</style>
# ...

# %%
#import bs4 as BeautifulSoup

from bs4 import BeautifulSoup

# %%
il_mental_health_soup = BeautifulSoup(il_mental_health_html)

# %%
type(il_mental_health_soup)
# Out:
# bs4.BeautifulSoup

# %%
il_mental_health_soup.title
# Out:
# <title>IDHS: Non-Crisis: Mental Health Partners/Providers</title>

# %%
il_mental_health_soup.select("p, h1")
# Out:
# [<h1>Non-Crisis: Mental Health Partners/Providers</h1>,
#  <p><a href="#content">Top of the page</a></p>,
#  <p class="brand"><img alt="IDHS" src="Custom_DHS/Config_WebSite/Images/IDHS-white.png"/><br/><strong>Illinois Department <span class="nowrap">of Human Services</span></strong><br/><small>JB Pritzker, Governor · <span class="nowrap">Dulce Quintero, Secretary</span></small></p>,
#  <p class="locator"><strong><a href="?item=26210">IDHS Office Locator</a></strong></p>,
#  <p class="helpline"><strong>IDHS Help Line</strong><br/>
#  							1-800-843-6154<br/>
#  							1-866-324-5553 TTY
#  						</p>,
#  <p class="copyright"><small>© 2023 Illinois Department of Human Services</small></p>]
